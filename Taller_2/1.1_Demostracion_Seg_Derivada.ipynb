# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import sympy as sym

# %%
#Demuestre la formula alternativa para la estimacion de la segunda derivada discreta:
#Para demostrarla voy a usar una funcion seno la cual ya conozco su segunda derivada, y comparar su grafica con la grafica generada por la ecuacion dada

x = np.linspace(0,2*np.pi,50)
h = x[1]-x[0]

# %%
sin = lambda x: np.sin(x)

# %%
f = sin(x)

# %%
f
# Out:
# array([ 0.00000000e+00,  1.27877162e-01,  2.53654584e-01,  3.75267005e-01,
#         4.90717552e-01,  5.98110530e-01,  6.95682551e-01,  7.81831482e-01,
#         8.55142763e-01,  9.14412623e-01,  9.58667853e-01,  9.87181783e-01,
#         9.99486216e-01,  9.95379113e-01,  9.74927912e-01,  9.38468422e-01,
#         8.86599306e-01,  8.20172255e-01,  7.40277997e-01,  6.48228395e-01,
#         5.45534901e-01,  4.33883739e-01,  3.15108218e-01,  1.91158629e-01,
#         6.40702200e-02, -6.40702200e-02, -1.91158629e-01, -3.15108218e-01,
#        -4.33883739e-01, -5.45534901e-01, -6.48228395e-01, -7.40277997e-01,
#        -8.20172255e-01, -8.86599306e-01, -9.38468422e-01, -9.74927912e-01,
#        -9.95379113e-01, -9.99486216e-01, -9.87181783e-01, -9.58667853e-01,
#        -9.14412623e-01, -8.55142763e-01, -7.81831482e-01, -6.95682551e-01,
#        -5.98110530e-01, -4.90717552e-01, -3.75267005e-01, -2.53654584e-01,
#        -1.27877162e-01, -2.44929360e-16])

# %%
def SegundaDerivadaDisc(x,f,h):
    return ((f(x+2)-2*f(x)+f(x-2))/(4*(h**2)))

# %%
def SegundaDerivada(x,f,h):
    return ((f(x+1)-2*f(x)+f(x-1))/(h**2))

# %%
SegundaDerivadaF = SegundaDerivadaDisc(x,sin,h)
SegundaDerivadaR = SegundaDerivada(x,sin,h)

# %%
SegundaDerivadaF
# Out:
# array([ 0.00000000e+00, -5.50685578e+00, -1.09232891e+01, -1.61603624e+01,
#        -2.11320829e+01, -2.57568153e+01, -2.99586214e+01, -3.36685078e+01,
#        -3.68255582e+01, -3.93779340e+01, -4.12837252e+01, -4.25116388e+01,
#        -4.30415124e+01, -4.28646456e+01, -4.19839425e+01, -4.04138642e+01,
#        -3.81801914e+01, -3.53196009e+01, -3.18790635e+01, -2.79150728e+01,
#        -2.34927174e+01, -1.86846122e+01, -1.35697062e+01, -8.23198595e+00,
#        -2.75909675e+00,  2.75909675e+00,  8.23198595e+00,  1.35697062e+01,
#         1.86846122e+01,  2.34927174e+01,  2.79150728e+01,  3.18790635e+01,
#         3.53196009e+01,  3.81801914e+01,  4.04138642e+01,  4.19839425e+01,
#         4.28646456e+01,  4.30415124e+01,  4.25116388e+01,  4.12837252e+01,
#         3.93779340e+01,  3.68255582e+01,  3.36685078e+01,  2.99586214e+01,
#         2.57568153e+01,  2.11320829e+01,  1.61603624e+01,  1.09232891e+01,
#         5.50685578e+00,  1.01282383e-14])

# %%
fig =plt.figure(figsize=(7,3))
ax = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,2)


ax.scatter(x,SegundaDerivadaF)
ax1.scatter(x,SegundaDerivadaR,Color='red')
# Out:
# <img src="data:image/png;base64,..." width="943.3333333333334">
# C:\Users\rafae\AppData\Local\Temp/ipykernel_13704/2546861834.py:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax1.scatter(x,SegundaDerivadaR,Color='red')
