# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import sympy as sym

# %%
#Show that the D4f operator is given by:
#Esto se hara usando la funcion seno y demostrando que la ecuacion dada equivale a la ecuacion real de la cuarta derivada, comparando sus graficas
x = np.linspace(0,2*np.pi,50)
h = x[1]-x[0]

# %%
sin = lambda x: np.sin(x)

# %%
f = sin(x)

# %%
f
# Out:
# array([ 0.00000000e+00,  1.27877162e-01,  2.53654584e-01,  3.75267005e-01,
#         4.90717552e-01,  5.98110530e-01,  6.95682551e-01,  7.81831482e-01,
#         8.55142763e-01,  9.14412623e-01,  9.58667853e-01,  9.87181783e-01,
#         9.99486216e-01,  9.95379113e-01,  9.74927912e-01,  9.38468422e-01,
#         8.86599306e-01,  8.20172255e-01,  7.40277997e-01,  6.48228395e-01,
#         5.45534901e-01,  4.33883739e-01,  3.15108218e-01,  1.91158629e-01,
#         6.40702200e-02, -6.40702200e-02, -1.91158629e-01, -3.15108218e-01,
#        -4.33883739e-01, -5.45534901e-01, -6.48228395e-01, -7.40277997e-01,
#        -8.20172255e-01, -8.86599306e-01, -9.38468422e-01, -9.74927912e-01,
#        -9.95379113e-01, -9.99486216e-01, -9.87181783e-01, -9.58667853e-01,
#        -9.14412623e-01, -8.55142763e-01, -7.81831482e-01, -6.95682551e-01,
#        -5.98110530e-01, -4.90717552e-01, -3.75267005e-01, -2.53654584e-01,
#        -1.27877162e-01, -2.44929360e-16])

# %%
def CuartaDerivative(x,f,h):
    return ((f(x+2)-4*f(x+1)+6*f(x)-4*f(x-1)+f(x-2))/(h**4))

# %%
CuartaDerivada = CuartaDerivative(x,sin,h)

# %%
fig =plt.figure(figsize=(7,3))
ax = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,2)


ax.scatter(x,np.sin(x))
ax1.scatter(x,CuartaDerivada,Color='red')
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\rafae\AppData\Local\Temp/ipykernel_24068/1501129055.py:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax1.scatter(x,CuartaDerivada,Color='red')
