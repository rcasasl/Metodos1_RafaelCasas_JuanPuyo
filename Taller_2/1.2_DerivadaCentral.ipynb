# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import sympy as sym

# %%
#Usando la defnicion de derivada central (con h = 0:05) estime la derivada de la funcion:
#def Function(x):
 #   return (1)/((np.exp((-x)**2))**(1/2))
    
x = sym.Symbol('x',Real=True)
func = 1/((1+sym.exp(-(x)**2))**(1/2))

# %%
func
# Out:
# (1 + exp(-x**2))**(-0.5)

# %%
f = sym.lambdify([x],func,'numpy')

# %%
f(0.3)
# Out:
# 0.7228311177528263

# %%
#a) En el intervalo -10<x<10.
x = np.linspace(-10,10,400)
y = f(x)
h = 0.05

# %%
#Function(x)
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f
# Out:
# <function _lambdifygenerated(x)>

# %%
def DerivativeC(x,f,h):
    return ((f(x+h)-f(x-h))/(2*h))

# %%
def Derivative(x,f,h):
    return ((f(x+h)-f(x))/h)

# %%
DerivadaC = DerivativeC(x,function,h)
Derivada = Derivative(x,function,h)

# %%
DerivadaC
# Out:
# array([ 2.00761390e-21,  3.29204420e-21,  5.38455455e-21,  8.78481158e-21,
#         1.42959676e-20,  2.32056094e-20,  3.75725441e-20,  6.06801033e-20,
#         9.77507240e-20,  1.57069368e-19,  2.51744925e-19,  4.02464468e-19,
#         6.41788344e-19,  1.02083003e-18,  1.61961672e-18,  2.56311522e-18,
#         4.04595394e-18,  6.37045612e-18,  1.00049926e-17,  1.56732664e-17,
#         2.44905546e-17,  3.81710347e-17,  5.93424269e-17,  9.20221930e-17,
#         1.42336277e-16,  2.19600950e-16,  3.37946736e-16,  5.18749342e-16,
#         7.94258660e-16,  1.21300135e-15,  1.84780169e-15,  2.80765675e-15,
#         4.25526940e-15,  6.43286328e-15,  9.70008656e-15,  1.45895110e-14,
#         2.18876687e-14,  3.27530481e-14,  4.88874280e-14,  7.27839630e-14,
#         1.08085402e-13,  1.60099883e-13,  2.36541524e-13,  3.48590830e-13,
#         5.12408693e-13,  7.51291985e-13,  1.09873390e-12,  1.60275655e-12,
# ...

# %%
Derivada
# Out:
# array([ 2.49449714e-21,  4.08650323e-21,  6.67757299e-21,  1.08838686e-20,
#         1.76948005e-20,  2.86949629e-20,  4.64155142e-20,  7.48890022e-20,
#         1.20523069e-19,  1.93472593e-19,  3.09788814e-19,  4.94776307e-19,
#         7.88222465e-19,  1.25252194e-18,  1.98526444e-18,  3.13868501e-18,
#         4.94963662e-18,  7.78565167e-18,  1.22155367e-17,  1.91172719e-17,
#         2.98424805e-17,  4.64664405e-17,  7.21670950e-17,  1.11798048e-16,
#         1.72752458e-16,  2.66261952e-16,  4.09344238e-16,  6.27715395e-16,
#         9.60132651e-16,  1.46485246e-15,  2.22920775e-15,  3.38377157e-15,
#         5.12324569e-15,  7.73718172e-15,  1.16550379e-14,  1.75120775e-14,
#         2.62454815e-14,  3.92341378e-14,  5.85013883e-14,  8.70082669e-14,
#         1.29076428e-13,  1.90996418e-13,  2.81900046e-13,  4.15008024e-13,
#         6.09409240e-13,  8.92591074e-13,  1.30402757e-12,  1.90025329e-12,
# ...

# %%
error = np.abs(DerivadaC-Derivada)

# %%
error
# Out:
# array([4.86883248e-22, 7.94459030e-22, 1.29301844e-21, 2.09905701e-21,
#        3.39883287e-21, 5.48935351e-21, 8.84297009e-21, 1.42088989e-20,
#        2.27723446e-20, 3.64032252e-20, 5.80438893e-20, 9.23118393e-20,
#        1.46434121e-19, 2.31691908e-19, 3.65647717e-19, 5.75569795e-19,
#        9.03682676e-19, 1.41519555e-18, 2.21054410e-18, 3.44400548e-18,
#        5.35192589e-18, 8.29540576e-18, 1.28246682e-17, 1.97758549e-17,
#        3.04161813e-17, 4.66610013e-17, 7.13975020e-17, 1.08966053e-16,
#        1.65873992e-16, 2.51851116e-16, 3.81406063e-16, 5.76114826e-16,
#        8.67976295e-16, 1.30431844e-15, 1.95495134e-15, 2.92256653e-15,
#        4.35781285e-15, 6.48108964e-15, 9.61396034e-15, 1.42243039e-14,
#        2.09910257e-14, 3.08965349e-14, 4.53585218e-14, 6.64171946e-14,
#        9.70005475e-14, 1.41299090e-13, 2.05293664e-13, 2.97496737e-13,
#        4.29990449e-13, 6.19875976e-13, 8.91291236e-13, 1.27821152e-12,
# ...

# %%
fig =plt.figure(figsize=(7,5))
ax = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,2)
ax2 = fig.add_subplot(2,2,3)

ax.plot(x,Derivada)
ax1.plot(x,DerivadaC,color='red')
ax2.plot(x,error)
# Out:
# <img src="data:image/png;base64,..." width="700">
